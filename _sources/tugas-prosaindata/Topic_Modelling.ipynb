# %% [markdown]
# # Topic Modelling

# %% [markdown]
# ## Crawling Data Dari Komentar Youtube

# %% [markdown]
# Program ini bertujuan untuk melakukan pengambilan data komentar pada sebuah video YouTube menggunakan Youtube Data API v3. Sebelum menggunakan program ini, pastikan bahwa layanan Youtube Data API telah diaktifkan dan API Key sudah di-generate.
#
# Jika Anda belum memiliki API Key, berikut adalah langkah-langkah untuk memperolehnya:
#
#
#
# 1.   Login ke Google Developer Console (https://console.developers.google.com/) dengan akun Google Anda.
#
# 2.   Buatlah project baru dan isi informasi yang diminta.
# 3.   Aktifkan layanan API pada halaman project dan cari Youtube Data API v3.
# 4.   Buat kredensial agar API tersebut dapat digunakan. Klik tombol "Create Credential" dan lengkapi form yang diminta.
#
# Anda dapat mengakses/melihat API Key pada tab Credentials di dashboard.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import library
import pandas as pd
from googleapiclient.discovery import build
import numpy as np
from string import punctuation
import re
import nltk

# %%
#Membuat function untuk crawling data
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:
		
		# extracting required info
		# from each result object
		for item in video_response['items']:
			
			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])
			
			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:
					
					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']
					
					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'], 
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %%
# isikan dengan api key Anda
api_key = 'AIzaSyAq6xFuf3fYN-2-ppUzOEJVOkfHuIi9ipI'

# url video =https://youtu.be/lcpdHr51a2s
video_id = "lcpdHr51a2s" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2023-05-10T12:08:32Z',
#   'Putra Putri',
#   'Ora pengaruh bro,,bah jokowi endorse bah cawe cawe. <br>ingat 2024 joe biden tidak tinggal diam.!! Catat.',
#   0],
#  ['2023-05-10T08:55:05Z',
#   'Taufik Hasan',
#   'Jelas dong JK &amp; Paloh ketar ketir,, kalau sampe ANIS kalah hilang kesempatan mereka ngeruk <b>DUIT</b> Rakyat,, melakui Proyek2 BUMN, karna jaman JokoWi mereka kekunci,, mangkanya <b>BOSOWA</b> Oleng,, Karna itu Keluarga JK turun bela ANIS,,,, 😅🤣',
#   1],
#  ['2023-05-10T08:04:32Z', 'a vian', 'jusufkala anda itu orqngtua loh', 0],
#  ['2023-05-10T07:12:57Z',
#   'ilham bobotoh',
#   'MURTAD YOHANES BUNGLON  PENGHIANAT BANGSA CAPRES KO HINA NENARA TAMU',
#   0],
#  ['2023-05-10T07:12:25Z',
#   'ilham bobotoh',
#   'MURTAD YOHANES BINGLON TAKUT KALAH MAKANYA DIA TAKUT KALAH',
#   1],
#  ['2023-05-10T07:11:39Z',
#   'ilham bobotoh',
#   'JK ITU PENGHIANAT BANGSA SI BUNGLON DARI YAMAN  SMUA KADRUN BADJINGAN KABEH PENGEN KORUPSI',
#   0],
#  ['2023-05-10T05:05:43Z', 'Is Kandar', 'Barangkali ada modal yg masuk', 1],
#  ['2023-05-10T04:55:47Z',
#   'RDS88 official',
#   'Saya tidak pro Jokowi dari awal yaa😂',
#   1],
#  ['2023-05-10T04:45:58Z',
#   'Aki Genit 79',
#   'Semua ingin jadi presiden, meskipun Tdk jadi presiden negara&#39; jadi presiden rumah tangga yg baik saja itu sudah 👍👍👍 .',
#   1],
#  ['2023-05-10T03:56:32Z',
#   'Sahi Rudin',
#   'Biarlah urusan politik jgn di kaitkan dg agama.biar mrk berkata apa2 tentang agamanya kita gak usah ikut2.mrk pnya tgg jawab sendiri.masalah peresiden ikut mendukung slh satu capres gak masalah yg milih kan rakyat.smg rakyat indonesia pada sadar bertahun tahun bgmn kehidupan raakyat.anda yg merasakan.',
#   0],
#  ['2023-05-10T03:00:49Z',
#   'WHeduez Ghiebaez',
#   'Kumis tipis masih belum puas karena pa di era Jokowi bisnis kumis tipis banyak yg lingkup atau tutup 😁😁😁',
#   1],
#  ['2023-05-10T02:13:45Z',
#   'akio ciputra',
#   'Si caplin jk ketar ketir! Maju terus pak jokowi!',
#   1],
#  ['2023-05-09T22:25:53Z',
#   'zainal arifin',
#   'Jokowi  petugas partai bukan negarawan sejati🤣🤣🤣',
#   1],
#  ['2023-05-09T22:17:35Z', 'Mobile Game', '😅 rekam jejak Anis benar ?', 0],
#  ['2023-05-09T18:29:32Z',
#   'petualang chanel😱',
#   'Awas JK udh terpilih cmn duduk di kursi',
#   1],
#  ['2023-05-09T17:02:43Z', 'berak', 'Chaplin nih tiap pilpres pasti nongol', 1],
#  ['2023-05-09T16:17:03Z',
#   'Muhammad SAUU',
#   'Marilah dukung channel TANPARAGI untuk pendidikan islam yang modern dan berfilosofi untuk kemajuan agama keluarga anda',
#   0],
#  ['2023-05-09T16:16:54Z',
#   'Muhammad SAUU',
#   'Marilah dukung channel TANPARAGI untuk pendidikan islam yang modern dan berfilosofi untuk kemajuan agama keluarga anda',
#   0],
#  ['2023-05-09T14:58:10Z',
#   '@stvsurya09',
#   'Cacing kena abu gosok pasti blingsatan boss 😅😅😅',
#   1],
#  ['2023-05-09T14:49:18Z', 'Muhammad Idris Idris', 'Maju terus pak anies', 0],
#  ['2023-05-09T14:47:44Z',
#   'arthavy',
#   'Duh produk gagal ko dipaksain ajah tuk jadi mimpin rakyat..kasar bed dah ah permainan politiknya lewat badut yg gagal memperbaiki Jakarta..pak Jokowi tak kan juga mau kalo program yg sudah berjalan dieranya rusak karena pemimpin yg pintar ngomong tok..harus pengganti pak Jokowi itu yg sejalan dalam nawacita negara..bukan produk karbitan gt',
#   2],
#  ['2023-05-09T13:26:02Z',
#   'goenawan dwi nugroho',
#   'Chaplin sendiri endorse ONTA goblok asal duitnya balik 🎉🎉😮😮😅<br>Chaplin GOBLOK',
#   0],
#  ['2023-05-09T12:29:30Z',
#   'Septia Munanda',
#   'Bisa ya pejabat publik sekaligus pejabat politik, ngeri ngeri, sama dgn pns pejabat publik jg pejabat politik, cara orba tp seolah anti orba..',
#   0],
#  ['2023-05-09T12:19:03Z',
#   'Fasos Griya Mandiri',
#   'Ya Allah selamatkan NKRI daru rorongan yg akan merusak tatan nuswantoro, caplin  wan abud  adalah garong yg akan merampas hak rakyat.',
#   1],
#  ['2023-05-09T11:59:45Z',
#   'hioe nyuk Tjhin',
#   'ANIES  segera ditangkap maling uang rakyet.dengan ini.tak ada masalah2 jg dingarang2 ANIES.',
#   0],
#  ['2023-05-09T11:23:13Z',
#   'Ahmad Sonhaji',
#   'Gass  pak. Jokowiii jgn hiraukan 🎉🎉🎉',
#   1],
#  ['2023-05-09T11:04:21Z',
#   'Apriliansyah channel',
#   'Anis mulai gelisah bentar lagi asam lambung naik',
#   2],
#  ['2023-05-09T10:05:35Z',
#   'Dodi Ruseno',
#   'Jokowi katanyakan planga plongo, bebek lumpuh..... Masa takut sih.... 😅😅😅',
#   1],
#  ['2023-05-09T10:03:18Z',
#   'sza rut',
#   'Anies pengen banget jadi presiden ya🤣🤣🤣',
#   0],
#  ['2023-05-09T09:30:01Z',
#   'ridwan dps',
#   'Sicaplon harusnya juga tidak cawe cawe  karena dia mantan wapres 2 x',
#   1],
#  ['2023-05-09T09:16:37Z',
#   'Sri Budi Purwanto',
#   'JK endorse anies dlm pilgub DKI ketika jadi wapres ...',
#   0],
#  ['2023-05-09T09:09:35Z',
#   'mohamad taofik',
#   'seorang pemimpin itu seharusnya netraljgn menjawab pertanyaan yg sifat nya sensitif,gk perlulah sbut nama2 capres yg menurut nya cocok didepan publik,kunci rapat2 mulut utk jg ht smua rakyatnya jg etika',
#   0],
#  ['2023-05-09T08:49:54Z',
#   'joko gida',
#   'Klu pak joko wi dianggap cawe cawe dan mencederai rakyat indonesia kata anis, lha sianus kampanye duluan apa ga mencederai rakyat bego kok dipelihara',
#   0],
#  ['2023-05-09T08:40:24Z',
#   'tai kucing rasa keju',
#   'Harusnya emg gaboleh dong presiden bgtu',
#   0],
#  ['2023-05-09T08:20:21Z',
#   'Surya Darma',
#   1],
#  ['2023-05-09T07:31:54Z',
#   'Heri Setyoko',
#   'Kok bisa ya, sudah jelas-jelas begitu masih menyangkal juga ndak cawe2. Hebatnya presidenku dlm hal &quot;nge-les&quot;',
#   0],
#  ['2023-05-09T14:29:20Z',
#   'dodo widodo',
#   'Guoblog, Presiden itu pembina dan pejabat politik, makanya ada MenkoPolHukam dibawahnya, paham',
#   0],
#  ['2023-05-09T06:40:14Z', 'Musrini Aku', 'Paluh mumet kliru pilihanya.', 1],
#  ['2023-05-09T06:22:03Z',
#   'Dian Safrizal',
#   'Takut y mereka..krj nyata Jokowi mangkanya di cintai rakyat..bkn merangkai kata hny untuk jabatan',
#   2],
#  ['2023-05-09T09:46:33Z', 'Agus S Singa terbangun', 'Ll', 0],
#  ['2023-05-09T09:46:16Z',
#   'Agus S Singa terbangun',
#   'USIR AGAMA TERORIS BAJINGAN YG RATUSAN TAHUN MEMBUNUH MENYIKSA MEMBANTAI MEMPERKOSA MERAMPOK KEKAYAAN NEGERI INI RATUSAN TAHUN DI BAWA KE NEGERI LELUHUR NYA MEREKA MEMBANGUN NEGARA DAN GEREJA MEWAH MEWAH HASIL NGERAMPOK DASAR BAJINGAN SAMPAI SEKARANG KATA MAHPUD BARU BERAPA TAHUN JADI MENTERI SUDAH LEBIH LIMA PULUH TNI DAN POLRI DI TEMBAK MATI OLEH TERORIS BAJINGAN KRISTEN BAHKAN JENERAL BINTANG SATU PUN DI TEMBAK MATI OLEH TERORIS BAJINGAN KRISTEN SIPIL LEBIH BANYAK LAGI BAHKAN A HARI LALU PESAWAT DI BAKAR PILOT DAN LIMA PENUMPANG BELUM KETAUAN DI BAWA KE MANA DAN DI A P AIN DASAR BAJINGAN BAHKAN BERAPA HARI LALU SEMBILAN PRAJURIT DI TEMBAK MATI OLEH TERORIS BAJINGAN KRISTEN DASAR AGAMA TERORIS  SEDANG ORMAS ISLAM DAN FPI SEJAK BERDIRI HINGGA KINI BELUM ADA YANG DI TEMBAK MATI OLEH ORMAS ISLAM DAN FPI TAPI DASAR AGAMA TERORIS BAJINGAN MALAH NGIPASIN APARAT UNTUK MEMBUBARKAN FPI DG ALASAN RADIKAL TERORIS OLEH BAJINGAN LUHUT LOLY SIGIT PADAHAL MEREKA BIANG NYA NI AGUS S SINGATERBANGUN KETUA SEKOLAH TINGGI ITA',
#   0],
#  ['2023-05-09T06:13:46Z',
#   'TheLirik',
#   'Lebih baik kandidat lain daripada PETUGAS PARTAI yang selama menjabat terkenal lewat jalur viral. Anis di awal proyek sumur resapan nya di cemooh tapi warga nya malah senang tuh dengan adanya sumur resapan. Jadi sebuah prestasi bukan hanya karena modal sliweran di berita tanpa tau prestasi nya apa selain Petugas partai',
#   1],
#  ['2023-05-09T06:03:21Z',
#   'yg bilang pencitraan tu orang yg iri aja g',
#   'Pinter bacot doang',
#   0],
#  ['2023-05-09T06:03:14Z',
#   'Rayhan Alganeyu',
#   'Itulah nama nya pemimpin yg peduli dengan rakyat dan ingin melanjutkan kemajuan negara kita, hanya orang yg berpikir seperti itu adalah orang yg gak maju',
#   1],
#   'Kalau calon ga serang menyerang?yang kepanasan pendukung bos yaman?',
#   0]]

# %%
#menjadikan dataframe
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'text', 'likeCount'])
df
# Out:
#               publishedAt       authorDisplayName  \
# 0    2023-05-10T12:08:32Z             Putra Putri
# 1    2023-05-10T08:55:05Z            Taufik Hasan
# 2    2023-05-10T08:04:32Z                  a vian
# 3    2023-05-10T07:12:57Z           ilham bobotoh
# 4    2023-05-10T07:12:25Z           ilham bobotoh
# ..                    ...                     ...
# 102  2023-05-09T14:42:19Z     Muhamad satim Da'wa
# 103  2023-05-09T10:04:15Z  Agus S Singa terbangun
# 104  2023-05-09T10:03:51Z  Agus S Singa terbangun
# 105  2023-05-08T08:52:27Z           vertikal cell
# 106  2023-05-08T09:56:55Z                SUGAN DI
#
#                                                   text  likeCount
# 0    Ora pengaruh bro,,bah jokowi endorse bah cawe ...          0
# 1    Jelas dong JK &amp; Paloh ketar ketir,, kalau ...          1
# 2                      jusufkala anda itu orqngtua loh          0
# 3    MURTAD YOHANES BUNGLON  PENGHIANAT BANGSA CAPR...          0
# 4    MURTAD YOHANES BINGLON TAKUT KALAH MAKANYA DIA...          1
# ..                                                 ...        ...
# 102  Beritakan jg dgn ayat ini dlm buku bibel yehez...          0
# 103                                                Lll          0
# 104  NAMA NYA AJA AGAMA TERORIS BAJINGAN YG RATUSAN...          0
# 105  biiasanya calon yg suka saling serang orang la...          0
# 106  Kalau calon ga serang menyerang?yang kepanasan...          0
#
# [107 rows x 4 columns]

# %%
cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
df.to_csv('capres2024.csv', index=False)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### 1. Symbol & Punctuation Removal, case folding
#
# Pada Tahap ini preprocessing yang dilakukan yaitu menghilangkan simbol dan tanda baca, serta melakukan case folding yaitu merubah seluruh huruf yang ada pada data menjadi huruf kecil

# %%
#proses menghilangkan simbol dan emoji
def remove_text_special (text):
  text = text.replace('\\t',"").replace('\\n',"").replace('\\u',"").replace('\\',"")
  text = text.encode('ascii', 'replace').decode('ascii')
  return text.replace("http://"," ").replace("https://", " ")
df['text'] = df['text'].apply(remove_text_special)
print(df['text'])
# Out:
# 0      Ora pengaruh bro,,bah jokowi endorse bah cawe ...
# 1      Jelas dong JK &amp; Paloh ketar ketir,, kalau ...
# 2                        jusufkala anda itu orqngtua loh
# 3      MURTAD YOHANES BUNGLON  PENGHIANAT BANGSA CAPR...
# 4      MURTAD YOHANES BINGLON TAKUT KALAH MAKANYA DIA...
#                              ...
# 102    Beritakan jg dgn ayat ini dlm buku bibel yehez...
# 103                                                  Lll
# 104    NAMA NYA AJA AGAMA TERORIS BAJINGAN YG RATUSAN...
# 105    biiasanya calon yg suka saling serang orang la...
# 106    Kalau calon ga serang menyerang?yang kepanasan...
# Name: text, Length: 107, dtype: object

# %%
#menghilangkan tanda baca
def remove_tanda_baca(text):
  text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
  return text

df['text'] = df['text'].apply(remove_tanda_baca)
df['text'].head(20)
# Out:
# 0     Ora pengaruh bro  bah jokowi endorse bah cawe ...
# 1     Jelas dong JK  amp  Paloh ketar ketir   kalau ...
# 2                       jusufkala anda itu orqngtua loh
# 3     MURTAD YOHANES BUNGLON  PENGHIANAT BANGSA CAPR...
# 4     MURTAD YOHANES BINGLON TAKUT KALAH MAKANYA DIA...
# 5     JK ITU PENGHIANAT BANGSA SI BUNGLON DARI YAMAN...
# 6                         Barangkali ada modal yg masuk
# 7                  Saya tidak pro Jokowi dari awal yaa
# 8     Semua ingin jadi presiden  meskipun Tdk jadi p...
# 9     Biarlah urusan politik jgn di kaitkan dg agama...
# 10    Kumis tipis masih belum puas karena pa di era ...
# 11     Si caplin jk ketar ketir  Maju terus pak jokowi
# 12     Jokowi  petugas partai bukan negarawan sejati
# 13                             rekam jejak Anis benar
# 14              Awas JK udh terpilih cmn duduk di kursi
# 15                Chaplin nih tiap pilpres pasti nongol
# 16    Marilah dukung channel TANPARAGI untuk pendidi...
# 17    Marilah dukung channel TANPARAGI untuk pendidi...
# 18      Cacing kena abu gosok pasti blingsatan boss
# 19                                 Maju terus pak anies
# Name: text, dtype: object

# %%
#proses menghilangkan angka
def remove_numbers (text):
  return re.sub(r"\d+", "", text)
df['text'] = df['text'].apply(remove_numbers)
df['text']
# Out:
# 0      Ora pengaruh bro  bah jokowi endorse bah cawe ...
# 1      Jelas dong JK  amp  Paloh ketar ketir   kalau ...
# 2                        jusufkala anda itu orqngtua loh
# 3      MURTAD YOHANES BUNGLON  PENGHIANAT BANGSA CAPR...
# 4      MURTAD YOHANES BINGLON TAKUT KALAH MAKANYA DIA...
#                              ...
# 102    Beritakan jg dgn ayat ini dlm buku bibel yehez...
# 103                                                  Lll
# 104    NAMA NYA AJA AGAMA TERORIS BAJINGAN YG RATUSAN...
# 105    biiasanya calon yg suka saling serang orang la...
# 106    Kalau calon ga serang menyerang yang kepanasan...
# Name: text, Length: 107, dtype: object

# %%
# proses casefolding
def casefolding(Comment):
  Comment = Comment.lower()
  return Comment
df['text'] = df['text'].apply(casefolding)
df['text']
# Out:
# 0      ora pengaruh bro  bah jokowi endorse bah cawe ...
# 1      jelas dong jk  amp  paloh ketar ketir   kalau ...
# 2                        jusufkala anda itu orqngtua loh
# 3      murtad yohanes bunglon  penghianat bangsa capr...
# 4      murtad yohanes binglon takut kalah makanya dia...
#                              ...
# 102    beritakan jg dgn ayat ini dlm buku bibel yehez...
# 103                                                  lll
# 104    nama nya aja agama teroris bajingan yg ratusan...
# 105    biiasanya calon yg suka saling serang orang la...
# 106    kalau calon ga serang menyerang yang kepanasan...
# Name: text, Length: 107, dtype: object

# %% [markdown]
# ### 2. Tokenizing
# Pada tahap ini preprocessing yang dilakukan adalah tokenizing. Tokenizing adalah metode untuk melakukan pemisahan kata dalam suatu kalimat dengan tujuan untuk proses analisis teks lebih lanjut

# %%
#proses tokenisasi
# from nltk.tokenize import TweetTokenizer
nltk.download('punkt')
# def word_tokenize(text):
#   tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
#   return tokenizer.tokenize(text)

df['review_token'] = df['text'].apply(lambda sentence: nltk.word_tokenize(sentence))
df['review_token']
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0      [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1      [jelas, dong, jk, amp, paloh, ketar, ketir, ka...
# 2                  [jusufkala, anda, itu, orqngtua, loh]
# 3      [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4      [murtad, yohanes, binglon, takut, kalah, makan...
#                              ...
# 102    [beritakan, jg, dgn, ayat, ini, dlm, buku, bib...
# 103                                                [lll]
# 104    [nama, nya, aja, agama, teroris, bajingan, yg,...
# 105    [biiasanya, calon, yg, suka, saling, serang, o...
# 106    [kalau, calon, ga, serang, menyerang, yang, ke...
# Name: review_token, Length: 107, dtype: object

# %%
cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
df['review_token'].to_csv('normalisasidata.csv', index=False)

# %% [markdown]
# ### 3. Word Normalization
# Pada tahap ini yang dilakukan yaitu normalisasi pada data. Hal tersebut dilakukan untuk merubah kata yang tidak baku menjadi kata baku

# %%
#Normalisasi kata tidak baku
normalize = pd.read_csv("/content/drive/MyDrive/prosaindata/normalisasidata.csv")

normalize_word_dict = {}

for row in normalize.iterrows():
  if row[0] not in normalize_word_dict:
    normalize_word_dict[row[0]] = row[1]

def normalized_term(comment):
  return [normalize_word_dict[term] if term in normalize_word_dict else term for term in comment]

df['comment_normalize'] = df['review_token'].apply(normalized_term)
df['comment_normalize'].head(20)
# Out:
# 0     [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1     [jelas, dong, jk, amp, paloh, ketar, ketir, ka...
# 2                 [jusufkala, anda, itu, orqngtua, loh]
# 3     [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4     [murtad, yohanes, binglon, takut, kalah, makan...
# 5     [jk, itu, penghianat, bangsa, si, bunglon, dar...
# 6                   [barangkali, ada, modal, yg, masuk]
# 7           [saya, tidak, pro, jokowi, dari, awal, yaa]
# 8     [semua, ingin, jadi, presiden, meskipun, tdk, ...
# 9     [biarlah, urusan, politik, jgn, di, kaitkan, d...
# 10    [kumis, tipis, masih, belum, puas, karena, pa,...
# 11    [si, caplin, jk, ketar, ketir, maju, terus, pa...
# 12    [jokowi, petugas, partai, bukan, negarawan, se...
# 13                          [rekam, jejak, anis, benar]
# 14     [awas, jk, udh, terpilih, cmn, duduk, di, kursi]
# 15         [chaplin, nih, tiap, pilpres, pasti, nongol]
# 16    [marilah, dukung, channel, tanparagi, untuk, p...
# 17    [marilah, dukung, channel, tanparagi, untuk, p...
# 18    [cacing, kena, abu, gosok, pasti, blingsatan, ...
# 19                            [maju, terus, pak, anies]
# Name: comment_normalize, dtype: object

# %% [markdown]
# ### 4. Stopwords Removal
# Pada tahap ini preprocessing yang dilakukan adalah menghilangkan kata yang tidak penting. Stopwords removal dilakukan 2 kali, yang pertama berdasarkan korpus yang ada di library python yaitu nltk, yang kedua berdasarkan file 'list_stopwords'

# %%
#Stopword Removal
nltk.download('stopwords')
from nltk.corpus import stopwords
txt_stopwords = stopwords.words('indonesian')

def stopwords_removal(filtering) :
  filtering = [word for word in filtering if word not in txt_stopwords]
  return filtering

df['stopwords_removal'] = df['comment_normalize'].apply(stopwords_removal)
df['stopwords_removal'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1     [jk, amp, paloh, ketar, ketir, sampe, anis, ka...
# 2                            [jusufkala, orqngtua, loh]
# 3     [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4     [murtad, yohanes, binglon, takut, kalah, takut...
# 5     [jk, penghianat, bangsa, si, bunglon, yaman, s...
# 6                        [barangkali, modal, yg, masuk]
# 7                                    [pro, jokowi, yaa]
# 8     [presiden, tdk, presiden, negara, presiden, ru...
# 9     [biarlah, urusan, politik, jgn, kaitkan, dg, a...
# 10    [kumis, tipis, puas, pa, era, jokowi, bisnis, ...
# 11         [si, caplin, jk, ketar, ketir, maju, jokowi]
# 12         [jokowi, petugas, partai, negarawan, sejati]
# 13                                 [rekam, jejak, anis]
# 14         [awas, jk, udh, terpilih, cmn, duduk, kursi]
# 15                      [chaplin, nih, pilpres, nongol]
# 16    [marilah, dukung, channel, tanparagi, pendidik...
# 17    [marilah, dukung, channel, tanparagi, pendidik...
# 18         [cacing, kena, abu, gosok, blingsatan, boss]
# 19                                        [maju, anies]
# Name: stopwords_removal, dtype: object

# %%
cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
df['stopwords_removal'].to_csv('stopwords1.csv', index=False)

# %%
#stopword removal 2
data_stopwords = pd.read_csv("/content/drive/MyDrive/prosaindata/stopwords1.csv")
print(data_stopwords)

def stopwords_removal2(filter) :
  filter = [word for word in filter if word not in data_stopwords]
  return filter

df['stopwords_removal_final'] = df['stopwords_removal'].apply(stopwords_removal2)
df['stopwords_removal_final'].head(20)
# Out:
#                                      stopwords_removal
# 0    ['ora', 'pengaruh', 'bro', 'bah', 'jokowi', 'e...
# 1    ['jk', 'amp', 'paloh', 'ketar', 'ketir', 'samp...
# 2                     ['jusufkala', 'orqngtua', 'loh']
# 3    ['murtad', 'yohanes', 'bunglon', 'penghianat',...
# 4    ['murtad', 'yohanes', 'binglon', 'takut', 'kal...
# ..                                                 ...
# 102  ['beritakan', 'jg', 'dgn', 'ayat', 'dlm', 'buk...
# 103                                            ['lll']
# 104  ['nama', 'nya', 'aja', 'agama', 'teroris', 'ba...
# 105  ['biiasanya', 'calon', 'yg', 'suka', 'serang',...
# 106  ['calon', 'ga', 'serang', 'menyerang', 'kepana...
#
# [107 rows x 1 columns]
# 0     [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1     [jk, amp, paloh, ketar, ketir, sampe, anis, ka...
# 2                            [jusufkala, orqngtua, loh]
# 3     [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4     [murtad, yohanes, binglon, takut, kalah, takut...
# 5     [jk, penghianat, bangsa, si, bunglon, yaman, s...
# 6                        [barangkali, modal, yg, masuk]
# 7                                    [pro, jokowi, yaa]
# 8     [presiden, tdk, presiden, negara, presiden, ru...
# 9     [biarlah, urusan, politik, jgn, kaitkan, dg, a...
# 10    [kumis, tipis, puas, pa, era, jokowi, bisnis, ...
# 11         [si, caplin, jk, ketar, ketir, maju, jokowi]
# 12         [jokowi, petugas, partai, negarawan, sejati]
# 13                                 [rekam, jejak, anis]
# 14         [awas, jk, udh, terpilih, cmn, duduk, kursi]
# 15                      [chaplin, nih, pilpres, nongol]
# 16    [marilah, dukung, channel, tanparagi, pendidik...
# 17    [marilah, dukung, channel, tanparagi, pendidik...
# 18         [cacing, kena, abu, gosok, blingsatan, boss]
# 19                                        [maju, anies]
# Name: stopwords_removal_final, dtype: object

# %% [markdown]
# ### 5. Stemming
# Pada tahap ini preprocessing yang dilakukan adalah stemming. Stemming adalah proses pemetaan dan penguraian bentuk dari suatu kata menjadi bentuk kata dasarnya.

# %%
pip install sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swifter in /usr/local/lib/python3.10/dist-packages (1.3.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (1.5.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2022.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.65.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.2.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from swifter) (6.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (23.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.22.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.0.0->swifter) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2022.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.4.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.16.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.21)

# %%
#proses stem
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import string
import swifter
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming (term):
  return stemmer.stem(term)

term_dict = {}
for document in df['stopwords_removal_final']:
  for term in document:
    if term not in term_dict:
      term_dict[term] = ''

# %%
print(len(term_dict))
print("-----------------------------")
# Out:
# 749
# -----------------------------

# %%
for term in term_dict:
  term_dict[term] = stemming(term)
  print(term,":",term_dict[term])

print(term_dict)
print("-----------------------------")
# Out:
# ora : ora
# pengaruh : pengaruh
# bro : bro
# bah : bah
# jokowi : jokowi
# endorse : endorse
# cawe : cawe
# br : br
# joe : joe
# biden : biden
# tinggal : tinggal
# diam : diam
# catat : catat
# jk : jk
# amp : amp
# paloh : paloh
# ketar : ketar
# ketir : tir
# sampe : sampe
# anis : anis
# kalah : kalah
# hilang : hilang
# kesempatan : sempat
# ngeruk : ngeruk
# b : b
# duit : duit
# rakyat : rakyat
# melakui : laku
# proyek : proyek
# bumn : bumn
# karna : karna
# jaman : jaman
# kekunci : kunci
# mangkanya : mangkanya
# bosowa : bosowa
# oleng : oleng
# keluarga : keluarga
# turun : turun
# bela : bela
# jusufkala : jusufkala
# orqngtua : orqngtua
# loh : loh
# murtad : murtad
# yohanes : yohanes
# bunglon : bunglon
# penghianat : penghianat
# bangsa : bangsa
# capres : capres
# ko : ko
# hina : hina
# nenara : nenara
# tamu : tamu
# binglon : binglon
# takut : takut
# si : si
# yaman : yaman
# smua : smua
# kadrun : kadrun
# badjingan : badjingan
# kabeh : kabeh
# pengen : ken
# korupsi : korupsi
# barangkali : barangkali
# modal : modal
# yg : yg
# masuk : masuk
# pro : pro
# yaa : yaa
# presiden : presiden
# tdk : tdk
# negara : negara
# rumah : rumah
# tangga : tangga
# biarlah : biar
# urusan : urus
# politik : politik
# jgn : jgn
# kaitkan : kait
# dg : dg
# agama : agama
# biar : biar
# mrk : mrk
# agamanya : agama
# gak : gak
# pnya : pnya
# tgg : tgg
# peresiden : residen
# mendukung : dukung
# slh : slh
# milih : milih
# smg : smg
# indonesia : indonesia
# sadar : sadar
# bertahun : tahun
# bgmn : bgmn
# kehidupan : hidup
# raakyat : raakyat
# merasakan : rasa
# kumis : kumis
# tipis : tipis
# puas : puas
# pa : pa
# era : era
# bisnis : bisnis
# lingkup : lingkup
# tutup : tutup
# caplin : caplin
# maju : maju
# petugas : tugas
# partai : partai
# negarawan : negarawan
# sejati : sejati
# rekam : rekam
# jejak : jejak
# awas : awas
# udh : udh
# terpilih : pilih
# cmn : cmn
# duduk : duduk
# kursi : kursi
# chaplin : chaplin
# nih : nih
# pilpres : pilpres
# nongol : nongol
# marilah : mari
# dukung : dukung
# channel : channel
# tanparagi : tanparagi
# pendidikan : didik
# islam : islam
# modern : modern
# berfilosofi : filosof
# kemajuan : maju
# cacing : cacing
# kena : kena
# abu : abu
# gosok : gosok
# blingsatan : blingsatan
# boss : boss
# anies : anies
# duh : duh
# produk : produk
# gagal : gagal
# dipaksain : dipaksain
# ajah : ajah
# tuk : tuk
# mimpin : mimpin
# kasar : kasar
# bed : bed
# dah : dah
# ah : ah
# permainan : main
# politiknya : politik
# badut : badut
# memperbaiki : baik
# jakarta : jakarta
# kalo : kalo
# program : program
# berjalan : jalan
# dieranya : era
# rusak : rusak
# pemimpin : pimpin
# pintar : pintar
# ngomong : ngomong
# tok : tok
# pengganti : ganti
# sejalan : jalan
# nawacita : nawacita
# karbitan : karbitan
# gt : gt
# onta : onta
# goblok : goblok
# duitnya : duit
# ya : ya
# pejabat : jabat
# publik : publik
# ngeri : ngeri
# dgn : dgn
# pns : pns
# jg : jg
# orba : orba
# tp : tp
# anti : anti
# allah : allah
# selamatkan : selamat
# nkri : nkri
# daru : daru
# rorongan : rorongan
# merusak : rusak
# tatan : tatan
# nuswantoro : nuswantoro
# wan : wan
# abud : abud
# garong : garong
# merampas : rampas
# hak : hak
# ditangkap : tangkap
# maling : maling
# uang : uang
# rakyet : rakyet
# dingarang : dingarang
# gass : gass
# jokowiii : jokowiii
# hiraukan : hirau
# gelisah : gelisah
# bentar : bentar
# asam : asam
# lambung : lambung
# katanyakan : katanyakan
# planga : planga
# plongo : plongo
# bebek : bebek
# lumpuh : lumpuh
# sih : sih
# banget : banget
# sicaplon : sicaplon
# mantan : mantan
# wapres : wapres
# x : x
# dlm : dlm
# pilgub : pilgub
# dki : dki
# netraljgn : netraljgn
# sifat : sifat
# nya : nya
# sensitif : sensitif
# gk : gk
# perlulah : perlu
# sbut : sbut
# nama : nama
# cocok : cocok
# didepan : depan
# kunci : kunci
# rapat : rapat
# mulut : mulut
# utk : utk
# ht : ht
# rakyatnya : rakyat
# etika : etika
# klu : klu
# joko : joko
# wi : wi
# dianggap : anggap
# mencederai : cedera
# lha : lha
# sianus : sianus
# kampanye : kampanye
# duluan : duluan
# ga : ga
# bego : bego
# dipelihara : pelihara
# emg : emg
# gaboleh : gaboleh
# bgtu : bgtu
# berkualitas : kualitas
# sumatera : sumatera
# memilih : pilih
# beliau : beliau
# for : for
# ri : ri
# merangkul : rangkul
# golongan : golong
# cilik : cilik
# pesan : pesan
# keren : keren
# rb : rb
# garis : garis
# bawahi : bawah
# pemilik : milik
# kekuasaan : kuasa
# republik : republik
# berbicara : bicara
# hilangnya : hilang
# pindahnya : pindah
# pindah : pindah
# berpindah : pindah
# berganti : ganti
# kewenangan : wenang
# menjalankan : jalan
# tangan : tangan
# menghargai : harga
# prinsip : prinsip
# dasar : dasar
# demokrasi : demokrasi
# namnya : namnya
# aja : aja
# mudtadin : mudtadin
# yihanes : yihanes
# ngomongnya : ngomongnya
# lancar : lancar
# gugup : gugup
# hasilnya : hasil
# kopong : kopong
# arifin : arifin
# cerdas : cerdas
# korban : korban
# hoax : hoax
# jd : jd
# bodoh : bodoh
# itukan : itu
# mnurut : mnurut
# selera : selera
# p : p
# ijasah : ijasah
# palsu : palsu
# ngeles : ngeles
# to : to
# mencla : mencla
# mincle : mincle
# yamg : yamg
# salah : salah
# kepentingan : penting
# trus : trus
# usulkan : usul
# cagub : cagub
# ribut : ribut
# maklumlah : maklum
# ijazahnya : ijazah
# sonhaji : sonhaji
# masaknya : masak
# matang : matang
# kali : kali
# basi : basi
# menyarankan : saran
# indenpenden : indenpenden
# calon : calon
# a : a
# ra : ra
# rasid : rasid
# baswedan : baswedan
# orang : orang
# sll : sll
# cari : cari
# kesalahan : salah
# lawan : lawan
# pdhal : pdhal
# dilanggar : langgar
# indonesi : indonesi
# sdh : sdh
# pd : pd
# tau : tau
# raja : raja
# alasan : alas
# bicara : bicara
# muter : muter
# bernarasi : narasi
# diruang : ruang
# hampa : hampa
# alias : alias
# halu : halu
# akut : akut
# praktek : praktek
# pilih : pilih
# suka : suka
# memutar : putar
# balikkan : balik
# fakta : fakta
# mencerminkan : cermin
# indonesiaan : indonesia
# jujur : jujur
# terbuka : buka
# rendah : rendah
# hati : hati
# dpt : dpt
# diterima : terima
# kakek : kakek
# neneknya : nenek
# buyutnya : buyut
# darah : darah
# ganjar : ganjar
# pranowo : pranowo
# aamiiin : aamiiin
# robbal : robbal
# alamiiin : alamiiin
# menyangkal : sangkal
# ndak : ndak
# hebatnya : hebat
# presidenku : presiden
# quot : quot
# nge : nge
# les : les
# guoblog : guoblog
# pembina : bina
# menkopolhukam : menkopolhukam
# dibawahnya : bawah
# paham : paham
# paluh : paluh
# mumet : mumet
# kliru : kliru
# pilihanya : pilihanya
# y : y
# krj : krj
# nyata : nyata
# cintai : cinta
# bkn : bkn
# merangkai : rangkai
# hny : hny
# jabatan : jabat
# ll : ll
# usir : usir
# teroris : teroris
# bajingan : bajing
# ratusan : ratus
# membunuh : bunuh
# menyiksa : siksa
# membantai : bantai
# memperkosa : perkosa
# merampok : rampok
# kekayaan : kaya
# negeri : negeri
# bawa : bawa
# leluhur : leluhur
# membangun : bangun
# gereja : gereja
# mewah : mewah
# hasil : hasil
# ngerampok : ngerampok
# mahpud : mahpud
# menteri : menteri
# puluh : puluh
# tni : tni
# polri : polri
# tembak : tembak
# mati : mati
# kristen : kristen
# jeneral : jeneral
# bintang : bintang
# sipil : sipil
# pesawat : pesawat
# bakar : bakar
# pilot : pilot
# penumpang : tumpang
# ketauan : tau
# ain : ain
# sembilan : sembilan
# prajurit : prajurit
# ormas : ormas
# fpi : fpi
# berdiri : diri
# ngipasin : ngipasin
# aparat : aparat
# membubarkan : bubar
# radikal : radikal
# luhut : luhut
# loly : loly
# sigit : sigit
# biang : biang
# ni : ni
# agus : agus
# s : s
# singaterbangun : singaterbangun
# ketua : ketua
# sekolah : sekolah
# ita : ita
# kandidat : kandidat
# menjabat : jabat
# terkenal : kenal
# jalur : jalur
# viral : viral
# sumur : sumur
# resapan : resap
# cemooh : cemooh
# warga : warga
# senang : senang
# tuh : tuh
# prestasi : prestasi
# sliweran : sliweran
# berita : berita
# pinter : pinter
# bacot : bacot
# doang : doang
# peduli : peduli
# melanjutkan : lanjut
# berpikir : pikir
# kau : kau
# salto : salto
# ente : ente
# pikir : pikir
# pdip : pdip
# teriak : teriak
# sby : sby
# asasi : asasi
# iro : iro
# hidup : hidup
# patung : patung
# bundaran : bundar
# hi : hi
# bambu : bambu
# hama : hama
# gulma : gulma
# bersihkan : sih
# krna : krna
# mengganggu : ganggu
# jalannya : jalan
# pembangunan : bangun
# sesuai : sesuai
# reelnya : reelnya
# bohir : bohir
# resah : resah
# heran : heran
# pasukan : pasu
# sakit : sakit
# maksa : maksa
# capers : capers
# rakus : rakus
# harta : harta
# lu : lu
# jdi : jdi
# barang : barang
# busuk : busuk
# laku : laku
# kadruuuuuuun : kadruuuuuuun
# paniiiiik : paniiiiik
# lll : lll
# grombolan : grombolan
# bubar : bubar
# cengeng : cengeng
# lo : lo
# kemane : kemane
# prabowo : prabowo
# tanding : tanding
# rezim : rezim
# byk : byk
# curangnya : curang
# mantap : mantap
# dp : dp
# monas : monas
# digunduli : gundul
# jalan : jalan
# mulus : mulus
# dilobangi : dilobangi
# item : item
# kelambui : kelambu
# tugu : tugu
# sepatu : sepatu
# sebelah : belah
# rotan : rotan
# dibongkar : bongkar
# pecat : pecat
# hebat : hebat
# sebahagian : sebahagian
# bentuk : bentuk
# perestasi : perestasi
# ter : ter
# bukti : bukti
# kemiri : kemiri
# iya : iya
# gubernur : gubernur
# ngajak : ngajak
# treakin : treakin
# intoleran : intoleran
# diskriminatif : diskriminatif
# rasiiisss : rasiiisss
# monyong : monyong
# congor : congor
# anjing : anjing
# ahok : ahok
# akal : akal
# bulus : bulus
# kepemimpinan : pimpin
# ummat : ummat
# lihat : lihat
# ntt : ntt
# bali : bal
# wilayah : wilayah
# mayoritas : mayoritas
# muslim : muslim
# kafir : kafir
# malu : malu
# bangor : bangor
# nyalon : nyalon
# legowo : legowo
# treak : treak
# ngatain : ngatain
# rasiiss : rasiiss
# aman : aman
# pilkada : pilkada
# seruet : seruet
# bersyahwat : syahwat
# monyet : monyet
# buang : buang
# syahwat : syahwat
# mauuukkk : mauuukkk
# kaliiikkk : kaliiikkk
# emange : emange
# doangan : doang
# visi : visi
# misi : misi
# kerja : kerja
# nysta : nysta
# wwlaupun : wwlaupun
# buatcpatung : buatcpatung
# idola : idola
# ku : ku
# president : president
# breowok : breowok
# boneka : boneka
# meraja : raja
# lela : lela
# golkar : golkar
# gorong : gorong
# formula : formula
# e : e
# usut : usut
# tuntas : tuntas
# cewe : cewe
# jok : jok
# dsr : dsr
# presdn : presdn
# ta : ta
# becus : becus
# iris : iris
# atur : atur
# pemilu : milu
# ha : ha
# dukungan : dukung
# bos : bos
# menang : menang
# dijadikan : jadi
# lebihnya : lebih
# minggu : minggu
# lebaran : lebaran
# udah : udah
# bikin : bikin
# dosa : dosa
# bilang : bilang
# gabecus : gabecus
# kanau : kanau
# niat : niat
# silahkan : silah
# pitnah : pitnah
# sanah : sanah
# sinih : sih
# insa : insa
# alloh : alloh
# gabakalan : gabakalan
# mema : mema
# ap : ap
# kon : kon
# pemitnah : pemitnah
# klo : klo
# komen : komen
# logis : logis
# emang : emang
# dajal : dajal
# n : n
# haknya : hak
# fir : fir
# aun : aun
# ama : ama
# href : href
# www : www
# youtube : youtube
# com : com
# watch : watch
# v : v
# lcpdhras : lcpdhras
# t : t
# ms : ms
# sarak : sarak
# irwan : irwan
# ee : ee
# pake : pake
# kasih : kasih
# yana : yana
# nisnis : nisnis
# panik : panik
# nyungsep : nyungsep
# ngawur : ngawur
# yoh : yoh
# yesus : yesus
# kepadamu : kepada
# sesungguhnya : sungguh
# makan : makan
# daging : daging
# anak : anak
# manusia : manusia
# minum : minum
# dirimu : diri
# tuhan : tuhan
# omongan : omong
# suku : suku
# kanibal : kanibal
# kepala : kepala
# zombie : zombie
# mendengar : dengar
# mengambil : ambil
# waras : waras
# markus : markus
# terbukti : bukti
# gila : gila
# lukas : lukas
# diserahkan : serah
# berdosa : dosa
# disalibkan : salib
# ketiga : tiga
# bangkit : bangkit
# mayat : mayat
# disuruh : suruh
# sang : sang
# rasul : rasul
# nyembah : nyembah
# roma : roma
# ayat : ayat
# mengaku : aku
# mulutmu : mulut
# percaya : percaya
# hatimu : hati
# membangkitkan : bangkit
# diselamatkan : selamat
# ajaran : ajar
# perzombian : perzombian
# azab : azab
# kubur : kubur
# siksa : siksa
# neraka : neraka
# dibenarkan : benar
# kesana : kesana
# kemari : kemari
# intinya : inti
# ngapain : ngapain
# hotbah : hotbah
# aneh : aneh
# sblm : sblm
# sklh : sklh
# dlu : dlu
# brti : brti
# gurunya : guru
# beritakan : berita
# buku : buku
# bibel : bibel
# yehezkiel : yehezkiel
# engkau : engkau
# bersundal : sundal
# bersetubuh : tubuh
# ngentot : ngentot
# tetangga : tetangga
# mu : mu
# org : org
# mesir : mesir
# aurat : aurat
# zombi : zombi
# biiasanya : biiasanya
# serang : serang
# jla : jla
# tk : tk
# menyerang : serang
# kepanasan : panas
# pendukung : dukung
# {'ora': 'ora', 'pengaruh': 'pengaruh', 'bro': 'bro', 'bah': 'bah', 'jokowi': 'jokowi', 'endorse': 'endorse', 'cawe': 'cawe', 'br': 'br', 'joe': 'joe', 'biden': 'biden', 'tinggal': 'tinggal', 'diam': 'diam', 'catat': 'catat', 'jk': 'jk', 'amp': 'amp', 'paloh': 'paloh', 'ketar': 'ketar', 'ketir': 'tir', 'sampe': 'sampe', 'anis': 'anis', 'kalah': 'kalah', 'hilang': 'hilang', 'kesempatan': 'sempat', 'ngeruk': 'ngeruk', 'b': 'b', 'duit': 'duit', 'rakyat': 'rakyat', 'melakui': 'laku', 'proyek': 'proyek', 'bumn': 'bumn', 'karna': 'karna', 'jaman': 'jaman', 'kekunci': 'kunci', 'mangkanya': 'mangkanya', 'bosowa': 'bosowa', 'oleng': 'oleng', 'keluarga': 'keluarga', 'turun': 'turun', 'bela': 'bela', 'jusufkala': 'jusufkala', 'orqngtua': 'orqngtua', 'loh': 'loh', 'murtad': 'murtad', 'yohanes': 'yohanes', 'bunglon': 'bunglon', 'penghianat': 'penghianat', 'bangsa': 'bangsa', 'capres': 'capres', 'ko': 'ko', 'hina': 'hina', 'nenara': 'nenara', 'tamu': 'tamu', 'binglon': 'binglon', 'takut': 'takut', 'si': 'si', 'yaman': 'yaman', 'smua': 'smua', 'kadrun': 'kadrun', 'badjingan': 'badjingan', 'kabeh': 'kabeh', 'pengen': 'ken', 'korupsi': 'korupsi', 'barangkali': 'barangkali', 'modal': 'modal', 'yg': 'yg', 'masuk': 'masuk', 'pro': 'pro', 'yaa': 'yaa', 'presiden': 'presiden', 'tdk': 'tdk', 'negara': 'negara', 'rumah': 'rumah', 'tangga': 'tangga', 'biarlah': 'biar', 'urusan
# -----------------------------

# %%
def get_stemming(document):
  return [term_dict[term] for term in document]

# %%
df['stemming'] = df['stopwords_removal_final'].swifter.apply(get_stemming)
# Out:
# Pandas Apply:   0%|          | 0/107 [00:00<?, ?it/s]

# %%
print(df['stemming'])
# Out:
# 0      [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1      [jk, amp, paloh, ketar, tir, sampe, anis, kala...
# 2                             [jusufkala, orqngtua, loh]
# 3      [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4      [murtad, yohanes, binglon, takut, kalah, takut...
#                              ...
# 102    [berita, jg, dgn, ayat, dlm, buku, bibel, yehe...
# 103                                                [lll]
# 104    [nama, nya, aja, agama, teroris, bajing, yg, r...
# 105    [biiasanya, calon, yg, suka, serang, orang, jl...
# 106    [calon, ga, serang, serang, panas, dukung, bos...
# Name: stemming, Length: 107, dtype: object

# %%
df.head(20)
# Out:
#              publishedAt     authorDisplayName  \
# 0   2023-05-10T12:08:32Z           Putra Putri
# 1   2023-05-10T08:55:05Z          Taufik Hasan
# 2   2023-05-10T08:04:32Z                a vian
# 3   2023-05-10T07:12:57Z         ilham bobotoh
# 4   2023-05-10T07:12:25Z         ilham bobotoh
# 5   2023-05-10T07:11:39Z         ilham bobotoh
# 6   2023-05-10T05:05:43Z             Is Kandar
# 7   2023-05-10T04:55:47Z        RDS88 official
# 8   2023-05-10T04:45:58Z          Aki Genit 79
# 9   2023-05-10T03:56:32Z            Sahi Rudin
# 10  2023-05-10T03:00:49Z      WHeduez Ghiebaez
# 11  2023-05-10T02:13:45Z          akio ciputra
# 12  2023-05-09T22:25:53Z         zainal arifin
# 13  2023-05-09T22:17:35Z           Mobile Game
# 14  2023-05-09T18:29:32Z     petualang chanel😱
# 15  2023-05-09T17:02:43Z                 berak
# 16  2023-05-09T16:17:03Z         Muhammad SAUU
# 17  2023-05-09T16:16:54Z         Muhammad SAUU
# 18  2023-05-09T14:58:10Z           @stvsurya09
# 19  2023-05-09T14:49:18Z  Muhammad Idris Idris
#
#                                                  text  likeCount  \
# 0   ora pengaruh bro  bah jokowi endorse bah cawe ...          0
# 1   jelas dong jk  amp  paloh ketar ketir   kalau ...          1
# 2                     jusufkala anda itu orqngtua loh          0
# 3   murtad yohanes bunglon  penghianat bangsa capr...          0
# 4   murtad yohanes binglon takut kalah makanya dia...          1
# 5   jk itu penghianat bangsa si bunglon dari yaman...          0
# 6                       barangkali ada modal yg masuk          1
# 7                saya tidak pro jokowi dari awal yaa           1
# 8   semua ingin jadi presiden  meskipun tdk jadi p...          1
# 9   biarlah urusan politik jgn di kaitkan dg agama...          0
# 10  kumis tipis masih belum puas karena pa di era ...          1
# 11   si caplin jk ketar ketir  maju terus pak jokowi           1
# 12   jokowi  petugas partai bukan negarawan sejati             1
# 13                           rekam jejak anis benar            0
# 14            awas jk udh terpilih cmn duduk di kursi          1
# 15              chaplin nih tiap pilpres pasti nongol          1
# 16  marilah dukung channel tanparagi untuk pendidi...          0
# 17  marilah dukung channel tanparagi untuk pendidi...          0
# 18    cacing kena abu gosok pasti blingsatan boss              1
# 19                               maju terus pak anies          0
#
#                                          review_token  \
# 0   [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1   [jelas, dong, jk, amp, paloh, ketar, ketir, ka...
# 2               [jusufkala, anda, itu, orqngtua, loh]
# 3   [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4   [murtad, yohanes, binglon, takut, kalah, makan...
# 5   [jk, itu, penghianat, bangsa, si, bunglon, dar...
# 6                 [barangkali, ada, modal, yg, masuk]
# 7         [saya, tidak, pro, jokowi, dari, awal, yaa]
# 8   [semua, ingin, jadi, presiden, meskipun, tdk, ...
# 9   [biarlah, urusan, politik, jgn, di, kaitkan, d...
# 10  [kumis, tipis, masih, belum, puas, karena, pa,...
# 11  [si, caplin, jk, ketar, ketir, maju, terus, pa...
# 12  [jokowi, petugas, partai, bukan, negarawan, se...
# 13                        [rekam, jejak, anis, benar]
# 14   [awas, jk, udh, terpilih, cmn, duduk, di, kursi]
# 15       [chaplin, nih, tiap, pilpres, pasti, nongol]
# 16  [marilah, dukung, channel, tanparagi, untuk, p...
# 17  [marilah, dukung, channel, tanparagi, untuk, p...
# 18  [cacing, kena, abu, gosok, pasti, blingsatan, ...
# 19                          [maju, terus, pak, anies]
#
#                                     comment_normalize  \
# 0   [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1   [jelas, dong, jk, amp, paloh, ketar, ketir, ka...
# 2               [jusufkala, anda, itu, orqngtua, loh]
# 3   [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4   [murtad, yohanes, binglon, takut, kalah, makan...
# 5   [jk, itu, penghianat, bangsa, si, bunglon, dar...
# 6                 [barangkali, ada, modal, yg, masuk]
# 7         [saya, tidak, pro, jokowi, dari, awal, yaa]
# 8   [semua, ingin, jadi, presiden, meskipun, tdk, ...
# 9   [biarlah, urusan, politik, jgn, di, kaitkan, d...
# 10  [kumis, tipis, masih, belum, puas, karena, pa,...
# 11  [si, caplin, jk, ketar, ketir, maju, terus, pa...
# 12  [jokowi, petugas, partai, bukan, negarawan, se...
# 13                        [rekam, jejak, anis, benar]
# 14   [awas, jk, udh, terpilih, cmn, duduk, di, kursi]
# 15       [chaplin, nih, tiap, pilpres, pasti, nongol]
# 16  [marilah, dukung, channel, tanparagi, untuk, p...
# 17  [marilah, dukung, channel, tanparagi, untuk, p...
# 18  [cacing, kena, abu, gosok, pasti, blingsatan, ...
# 19                          [maju, terus, pak, anies]
#
#                                     stopwords_removal  \
# 0   [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1   [jk, amp, paloh, ketar, ketir, sampe, anis, ka...
# 2                          [jusufkala, orqngtua, loh]
# 3   [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4   [murtad, yohanes, binglon, takut, kalah, takut...
# 5   [jk, penghianat, bangsa, si, bunglon, yaman, s...
# 6                      [barangkali, modal, yg, masuk]
# 7                                  [pro, jokowi, yaa]
# 8   [presiden, tdk, presiden, negara, presiden, ru...
# 9   [biarlah, urusan, politik, jgn, kaitkan, dg, a...
# 10  [kumis, tipis, puas, pa, era, jokowi, bisnis, ...
# 11       [si, caplin, jk, ketar, ketir, maju, jokowi]
# 12       [jokowi, petugas, partai, negarawan, sejati]
# 13                               [rekam, jejak, anis]
# 14       [awas, jk, udh, terpilih, cmn, duduk, kursi]
# 15                    [chaplin, nih, pilpres, nongol]
# 16  [marilah, dukung, channel, tanparagi, pendidik...
# 17  [marilah, dukung, channel, tanparagi, pendidik...
# 18       [cacing, kena, abu, gosok, blingsatan, boss]
# 19                                      [maju, anies]
#
#                               stopwords_removal_final  \
# 0   [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1   [jk, amp, paloh, ketar, ketir, sampe, anis, ka...
# 2                          [jusufkala, orqngtua, loh]
# 3   [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4   [murtad, yohanes, binglon, takut, kalah, takut...
# 5   [jk, penghianat, bangsa, si, bunglon, yaman, s...
# 6                      [barangkali, modal, yg, masuk]
# 7                                  [pro, jokowi, yaa]
# 8   [presiden, tdk, presiden, negara, presiden, ru...
# 9   [biarlah, urusan, politik, jgn, kaitkan, dg, a...
# 10  [kumis, tipis, puas, pa, era, jokowi, bisnis, ...
# 11       [si, caplin, jk, ketar, ketir, maju, jokowi]
# 12       [jokowi, petugas, partai, negarawan, sejati]
# 13                               [rekam, jejak, anis]
# 14       [awas, jk, udh, terpilih, cmn, duduk, kursi]
# 15                    [chaplin, nih, pilpres, nongol]
# 16  [marilah, dukung, channel, tanparagi, pendidik...
# 17  [marilah, dukung, channel, tanparagi, pendidik...
# 18       [cacing, kena, abu, gosok, blingsatan, boss]
# 19                                      [maju, anies]
#
#                                              stemming
# 0   [ora, pengaruh, bro, bah, jokowi, endorse, bah...
# 1   [jk, amp, paloh, ketar, tir, sampe, anis, kala...
# 2                          [jusufkala, orqngtua, loh]
# 3   [murtad, yohanes, bunglon, penghianat, bangsa,...
# 4   [murtad, yohanes, binglon, takut, kalah, takut...
# 5   [jk, penghianat, bangsa, si, bunglon, yaman, s...
# 6                      [barangkali, modal, yg, masuk]
# 7                                  [pro, jokowi, yaa]
# 8   [presiden, tdk, presiden, negara, presiden, ru...
# 9   [biar, urus, politik, jgn, kait, dg, agama, bi...
# 10  [kumis, tipis, puas, pa, era, jokowi, bisnis, ...
# 11         [si, caplin, jk, ketar, tir, maju, jokowi]
# 12         [jokowi, tugas, partai, negarawan, sejati]
# 13                               [rekam, jejak, anis]
# 14          [awas, jk, udh, pilih, cmn, duduk, kursi]
# 15                    [chaplin, nih, pilpres, nongol]
# 16  [mari, dukung, channel, tanparagi, didik, isla...
# 17  [mari, dukung, channel, tanparagi, didik, isla...
# 18       [cacing, kena, abu, gosok, blingsatan, boss]
# 19                                      [maju, anies]

# %% [markdown]
# ## Feature Extraction (TF-IDF)

# %%
def joinkata(data):
  kalimat = ""
  for i in data:
    kalimat += i
    kalimat += " "
  return kalimat

text = df['stemming'].swifter.apply(joinkata)
text
# Out:
# Pandas Apply:   0%|          | 0/107 [00:00<?, ?it/s]
# 0      ora pengaruh bro bah jokowi endorse bah cawe c...
# 1      jk amp paloh ketar tir sampe anis kalah hilang...
# 2                                jusufkala orqngtua loh
# 3      murtad yohanes bunglon penghianat bangsa capre...
# 4        murtad yohanes binglon takut kalah takut kalah
#                              ...
# 102    berita jg dgn ayat dlm buku bibel yehezkiel a ...
# 103                                                 lll
# 104    nama nya aja agama teroris bajing yg ratus bun...
# 105         biiasanya calon yg suka serang orang jla tk
# 106       calon ga serang serang panas dukung bos yaman
# Name: stemming, Length: 107, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorize document using TF-IDF
tfidf = TfidfVectorizer(lowercase=True,
                        stop_words='english',
                        ngram_range = (1,1)
                        )

# Fit and Transform the documents
X = tfidf.fit_transform(text)

# %%
print(X)
# Out:
#   (0, 122)	0.2509770726148333
#   (0, 150)	0.2509770726148333
#   (0, 628)	0.2509770726148333
#   (0, 80)	0.2509770726148333
#   (0, 265)	0.2509770726148333
#   (0, 97)	0.1879552670570942
#   (0, 123)	0.39142001901273193
#   (0, 174)	0.20488192310072553
#   (0, 268)	0.15308563254945073
#   (0, 44)	0.5019541452296666
#   (0, 99)	0.23057964401400946
#   (0, 472)	0.2509770726148333
#   (0, 447)	0.2509770726148333
#   (1, 67)	0.1934840655358963
#   (1, 646)	0.1934840655358963
#   (1, 294)	0.15794824213755035
#   (1, 444)	0.1934840655358963
#   (1, 95)	0.1934840655358963
#   (1, 361)	0.17775921317768006
#   (1, 325)	0.17775921317768006
#   (1, 256)	0.1934840655358963
#   (1, 287)	0.3869681310717926
#   (1, 108)	0.1934840655358963
#   (1, 512)	0.1666022528746911
#   (1, 327)	0.17775921317768006
#   :	:
#   (104, 8)	0.05957632240178965
#   (104, 144)	0.2206832822883817
#   (104, 184)	0.05517082057209542
#   (104, 405)	0.062368355791993686
#   (104, 438)	0.13088316042295325
#   (104, 246)	0.10673423262777654
#   (104, 3)	0.10350729574879614
#   (104, 148)	0.05336711631388827
#   (104, 410)	0.04896161448419404
#   (104, 676)	0.038346906566598414
#   (105, 631)	0.401514180987433
#   (105, 264)	0.401514180987433
#   (105, 580)	0.3688822885456953
#   (105, 81)	0.401514180987433
#   (105, 600)	0.3688822885456953
#   (105, 448)	0.2899450038127995
#   (105, 117)	0.34572959240011625
#   (105, 676)	0.20152852278374506
#   (106, 459)	0.3618454629498519
#   (106, 580)	0.6648750594290751
#   (106, 94)	0.2953879154858563
#   (106, 117)	0.31157226902877233
#   (106, 184)	0.2612990751076928
#   (106, 168)	0.2527564025581437
#   (106, 671)	0.33243752971453755

# %%
df_tfidf = pd.DataFrame(
    X.toarray().T, columns=[f'D{i+1}' for i in range(len(text))], index=tfidf.get_feature_names_out()
)
df_tfidf
# Out:
#           D1   D2   D3        D4        D5   D6   D7   D8   D9       D10  ...  \
# aamiiin  0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# abu      0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# abud     0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# agama    0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.241344  ...
# agus     0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# ...      ...  ...  ...       ...       ...  ...  ...  ...  ...       ...  ...
# yoh      0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# yohanes  0.0  0.0  0.0  0.294951  0.304746  0.0  0.0  0.0  0.0  0.000000  ...
# youtube  0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# zombi    0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
# zombie   0.0  0.0  0.0  0.000000  0.000000  0.0  0.0  0.0  0.0  0.000000  ...
#
#          D98  D99      D100  D101  D102      D103  D104      D105  D106  D107
# aamiiin  0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.000000   0.0   0.0
# abu      0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.000000   0.0   0.0
# abud     0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.000000   0.0   0.0
# agama    0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.103507   0.0   0.0
# agus     0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.057216   0.0   0.0
# ...      ...  ...       ...   ...   ...       ...   ...       ...   ...   ...
# yoh      0.0  0.0  0.028979   0.0   0.0  0.000000   0.0  0.000000   0.0   0.0
# yohanes  0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.000000   0.0   0.0
# youtube  0.0  0.0  0.049905   0.0   0.0  0.182345   0.0  0.000000   0.0   0.0
# zombi    0.0  0.0  0.000000   0.0   0.0  0.000000   0.0  0.076400   0.0   0.0
# zombie   0.0  0.0  0.144893   0.0   0.0  0.000000   0.0  0.000000   0.0   0.0
#
# [683 rows x 107 columns]

# %% [markdown]
# ## Latent Semantic Analysis (LSA)

# %%
from sklearn.decomposition import TruncatedSVD

# %%
# Define the number of topics or components
num_components=10

# Create SVD object
lsa = TruncatedSVD(n_components=num_components, n_iter=100, random_state=42)

# Fit SVD model on data
lsa.fit_transform(X)

# Get Singular values and Components 
Sigma = lsa.singular_values_ 
V_transpose = lsa.components_.T

# %%
# Print the topics with their terms
terms = tfidf.get_feature_names_out()

for index, component in enumerate(lsa.components_):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:5]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['bajing', 'teroris', 'tembak', 'mati', 'dasar']
# Topic 1:  ['ll', 'sarak', 'kemiri', 'lll', 'yana']
# Topic 2:  ['anies', 'yg', 'maju', 'jk', 'anis']
# Topic 3:  ['lll', 'sarak', 'yana', 'yg', 'anies']
# Topic 4:  ['maju', 'anies', 'channel', 'didik', 'filosof']
# Topic 5:  ['anies', 'presiden', 'banget', 'jd', 'negara']
# Topic 6:  ['anis', 'presiden', 'ri', 'mantap', 'bos']
# Topic 7:  ['presiden', 'yg', 'channel', 'didik', 'filosof']
# Topic 8:  ['cawe', 'jokowi', 'presiden', 'br', 'si']
# Topic 9:  ['cawe', 'br', 'mantap', 'ri', 'anis']
